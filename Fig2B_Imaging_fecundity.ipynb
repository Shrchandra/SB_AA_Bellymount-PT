# %%
### Import libraries ###

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats

### Import data ####

d=pd.read_csv('/Users/shruthibalachandra/Documents/Shruthi_for_mac/Amodeo_Lab/Python/BM_status_fecundity_v2.csv')
d.head()
# Out:
#    Unnamed: 0  InVial statusV  On Bench statusB  On Mcroscope statusM  \
# 0         1.0    17.0   alive         9   alive           0.0    dead
# 1         2.0    26.0   alive         0   alive           0.0   alive
# 2         3.0    12.0   alive         1   alive           0.0   alive
# 3         4.0     0.0   alive         0    dead           1.0   alive
# 4         5.0    11.0   alive         0    dead           4.0   alive
#
#    On Laser statusL  all_flies:  ...  AOn Laser AstatusL  Unnamed: 29  \
# 0       7.0    dead         NaN  ...        1.0    alive          NaN
# 1       1.0   alive         NaN  ...        2.0    alive          NaN
# 2       1.0    dead         NaN  ...        1.0    alive          NaN
# 3       2.0   alive         NaN  ...        1.0    alive          NaN
# 4       1.0   alive         NaN  ...        0.0    alive          NaN
#
#    FAll_status  FAll_bins  FAll_Frequency alive_flies:.1  FAlive_Status  \
# ...

# %%
# Read the CSV file into a DataFrame
d=pd.read_csv('/Users/shruthibalachandra/Documents/Shruthi_for_mac/Amodeo_Lab/Python/BM_status_fecundity_v2.csv')


# Set up plot aesthetics
plt.figure(figsize = (4,3))
plt.style.use('seaborn')
sns.set_style("whitegrid")
sns.set_palette

# Plot the barplot
sns.barplot(x='FAll_bins', y='FAll_Frequency', data=d, palette='viridis', hue='FAll_status', ci=None)

# Additional plot customizations
plt.xlabel('Number of eggs/female', fontsize=10)
plt.ylabel('Percent of females', fontsize=10)
plt.legend(["In Foodvial", "On Bench", "On Microscope", "On Laser"], fontsize=10, loc='upper right')
plt.xticks(size=10)
plt.yticks(size=10)

# Save the plot as a PNG file
plt.savefig('/Users/shruthibalachandra/Documents/Shruthi_for_mac/Amodeo_Lab/Python/BM_Figure_Plots/Allimaged_BM_egg.pdf', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
# Drop rows with NaN values
d_clean = d.dropna(subset=['InVial'])

# Define data
InVial = d_clean['InVial']
OnBench = d_clean['On Bench']
OnMcroscope = d_clean['On Mcroscope']
OnLaser = d_clean['On Laser']

# Mean
mean = np.mean(InVial)

# Median
median = np.median(InVial)

# Standard Deviation
std_dev = np.std(InVial)

# Standard Error of the Mean (SEM)
sem = stats.sem(InVial)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
print("Standard Error of the Mean:", sem)
# Out:
# Mean: 9.945945945945946
# Median: 10.0
# Standard Deviation: 9.331567887569665
# Standard Error of the Mean: 1.5552613145949443

# %%
# Drop rows with NaN values
d_clean = d.dropna(subset=['On Bench'])

# Define data for stats
OnBench = d_clean['On Bench']

# Mean
mean = np.mean(OnBench)

# Median
median = np.median(OnBench)

# Standard Deviation
std_dev = np.std(OnBench)

# Standard Error of the Mean (SEM)
sem = stats.sem(OnBench)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
print("Standard Error of the Mean:", sem)
# Out:
# Mean: 4.419047619047619
# Median: 1.0
# Standard Deviation: 7.183023573983252
# Standard Error of the Mean: 0.7043534109680303

# %%
# Drop rows with NaN values
d_clean = d.dropna(subset=['On Mcroscope'])

# Define data
OnMcroscope = d_clean['On Mcroscope']

# Mean
mean = np.mean(OnMcroscope)

# Median
median = np.median(OnMcroscope)

# Standard Deviation
std_dev = np.std(OnMcroscope)

# Standard Error of the Mean (SEM)
sem = stats.sem(OnMcroscope)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
print("Standard Error of the Mean:", sem)
# Out:
# Mean: 0.7446808510638298
# Median: 0.0
# Standard Deviation: 1.780127716029947
# Standard Error of the Mean: 0.26246551265700474

# %%
# Drop rows with NaN values
d_clean = d.dropna(subset=['On Laser'])

# Define data
OnLaser = d_clean['On Laser']

# Mean
mean = np.mean(OnLaser)

# Median
median = np.median(OnLaser)

# Standard Deviation
std_dev = np.std(OnLaser)

# Standard Error of the Mean (SEM)
sem = stats.sem(OnLaser)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
print("Standard Error of the Mean:", sem)
# Out:
# Mean: 2.689655172413793
# Median: 1.0
# Standard Deviation: 5.795976299158259
# Standard Error of the Mean: 0.7676958149017219

# %%
# Drop rows with NaN values
d_clean = d.dropna(subset=['InVial', 'On Bench', 'On Mcroscope', 'On Laser'])

# Define data
InVial = d_clean['InVial']
OnBench = d_clean['On Bench']
OnMcroscope = d_clean['On Mcroscope']
OnLaser = d_clean['On Laser']

# Perform t-test between InVial and OnBench
t_statistic, p_value = stats.ttest_ind(InVial, OnBench, equal_var=False)  # Assuming unequal variances

print("T-Statistic:", t_statistic)
print("P-value:", p_value)

# Perform t-test between InVial and OnMcroscope
t_statistic, p_value = stats.ttest_ind(InVial, OnMcroscope, equal_var=False)  # Assuming unequal variances

print("T-Statistic:", t_statistic)
print("P-value:", p_value)

# Perform t-test between InVial and OnLaser
t_statistic, p_value = stats.ttest_ind(InVial, OnLaser, equal_var=False)  # Assuming unequal variances

print("T-Statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-Statistic: 2.3238821174419773
# P-value: 0.023052988282199306
# T-Statistic: 5.728803950952683
# P-value: 1.2093782494357353e-06
# T-Statistic: 5.560589229831536
# P-value: 2.15436784458505e-06
