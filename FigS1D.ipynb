# %%
#Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats


d=pd.read_csv('/Users/shruthibalachandra/Documents/Shruthi_for_mac/Amodeo_Lab/Python/Imaging_conditions_status_v34.csv')

d.head()

import matplotlib.pyplot as plt
import seaborn as sns

#defining fig size
plt.figure(figsize = (2,3))
sns.set_style("whitegrid")

# Define custom color palettes
custom_palette1 = ["#006ca5"]
custom_palette2 = ["#20B2AA"]

# Convert 'ConditionsDayA' and 'ConditionsDayD' columns to strings
d['ConditionsDayA'] = d['ConditionsDayA']
d['ConditionsDayD'] = d['ConditionsDayD']

# Define the data
conditions = ['Foodvial', 'Bench', 'Microscope', 'Imaged']
average_a = [100, 75, 83.3333333333333, 80]
average_d = [0, 25, 16.6666666666667, 20]


# Plot bars for AverageA
plt.bar(conditions, average_a, color=custom_palette1[0], label='Alive')

# Plot bars for AverageD on top of AverageA
plt.bar(conditions, average_d, bottom=average_a, color=custom_palette2[0], label='Dead')


# Additional plot customizations
plt.xlabel('Imaging conditions', fontsize=10)
plt.ylabel('Percent of flies', fontsize=10)
plt.xticks(size=10, rotation=35, rotation_mode='anchor', ha='right')
plt.yticks(size=10)
plt.legend(['Alive', 'Dead'])
# Save the plot as a PNG file
#plt.savefig('/Users/shruthibalachandra/Documents/Shruthi_for_mac/Amodeo_Lab/Python/BM_Figure_Plots/Status_BM_Alive_Dead_stacked.pdf', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
#Libraries
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
d=pd.read_csv('/Users/shruthibalachandra/Documents/Shruthi_for_mac/Amodeo_Lab/Python/BM_status_fecundity_v3.csv')
d.head()
# Out:
#    Unnamed: 0  InVial  InVial/35.625 statusV  On Bench  On Bench/35.625  \
# 0         1.0    17.0       0.459459   alive       9.0         0.085714
# 1         2.0    26.0       0.702703   alive       0.0         0.000000
# 2         3.0    12.0       0.324324   alive       1.0         0.009524
# 3         4.0     0.0       0.000000   alive       0.0         0.000000
# 4         5.0    11.0       0.297297   alive       0.0         0.000000
#
#   statusB  On Mcroscope  On Mcroscope/35.625 statusM  ...  10statusV  \
# 0   alive           0.0             0.000000    dead  ...      alive
# 1   alive           0.0             0.000000   alive  ...      alive
# 2   alive           0.0             0.000000   alive  ...      alive
# 3    dead           1.0             0.021277   alive  ...      alive
# 4    dead           4.0             0.085106   alive  ...      alive
#
#    10On Bench 10On Bench/To  10statusB  10On Mcroscope 10On Mcroscope/To  \
# ...

# %%
bins = [-1, 0, 1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# Calculate the total number of samples in each group
group_counts = d['1InVial'].value_counts()


# Calculate the frequency distribution with custom bins
frequency_distribution = pd.cut(d['1InVial'], bins=bins).value_counts()


# Normalize the frequency distribution by dividing by the total counts
normalized_distribution = frequency_distribution / group_counts

# Print the normalized distribution

print(frequency_distribution)
print(normalized_distribution)
# Out:
# (-1, 0]     6
# (5, 10]     6
# (25, 30]    6
# (1, 5]      4
# (10, 15]    4
# (0, 1]      3
# (15, 20]    3
# (20, 25]    3
# (30, 35]    3
# (40, 45]    1
# (45, 50]    1
# (35, 40]    0
# Name: 1InVial, dtype: int64
# (-1, 0]    NaN
# (5, 10]    NaN
# (25, 30]   NaN
# (1, 5]     NaN
# (10, 15]   NaN
# (0, 1]     NaN
# (15, 20]   NaN
# (20, 25]   NaN
# (30, 35]   NaN
# (40, 45]   NaN
# (45, 50]   NaN
# (35, 40]   NaN
# 0.0        NaN
# 8.0        NaN
# 1.0        NaN
# 5.0        NaN
# 10.0       NaN
# 30.0       NaN
# 28.0       NaN
# 17.0       NaN
# 35.0       NaN
# 11.0       NaN
# 42.0       NaN
# 26.0       NaN
# 47.0       NaN
# 9.0        NaN
# 16.0       NaN
# 14.0       NaN
# 27.0       NaN
# 25.0       NaN
# 31.0       NaN
# 13.0       NaN
# 12.0       NaN
# 23.0       NaN
# 21.0       NaN
# 4.0        NaN
# Name: 1InVial, dtype: float64
# ...

# %%
bins = [-1, 0, 1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# Calculate the total number of samples in each group
group_counts = d['1On Bench'].value_counts()


# Calculate the frequency distribution with custom bins
frequency_distribution = pd.cut(d['1On Bench'], bins=bins).value_counts()


# Normalize the frequency distribution by dividing by the total counts
normalized_distribution = frequency_distribution / group_counts

# Print the normalized distribution

print(frequency_distribution)
print(normalized_distribution)
# Out:
# (-1, 0]     16
# (1, 5]      10
# (0, 1]       9
# (5, 10]      4
# (25, 30]     3
# (20, 25]     2
# (10, 15]     0
# (15, 20]     0
# (30, 35]     0
# (35, 40]     0
# (40, 45]     0
# (45, 50]     0
# Name: 1On Bench, dtype: int64
# (-1, 0]    NaN
# (1, 5]     NaN
# (0, 1]     NaN
# (5, 10]    NaN
# (25, 30]   NaN
# (20, 25]   NaN
# (10, 15]   NaN
# (15, 20]   NaN
# (30, 35]   NaN
# (35, 40]   NaN
# (40, 45]   NaN
# (45, 50]   NaN
# 0.0        NaN
# 1.0        NaN
# 2.0        NaN
# 3.0        NaN
# 10.0       NaN
# 4.0        NaN
# 6.0        NaN
# 30.0       NaN
# 25.0       NaN
# 5.0        NaN
# 21.0       NaN
# 29.0       NaN
# Name: 1On Bench, dtype: float64
# /var/folders/k3/54x11nt55_17p1yfsph643kc0000gn/T/ipykernel_18457/2994829021.py:15: RuntimeWarning: '<' not supported between instances of 'float' and 'pandas._libs.interval.Interval', sort order is undefined for incomparable objects.
#   normalized_distribution = frequency_distribution / group_counts

# %%
bins = [-1, 0, 1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# Calculate the total number of samples in each group
group_counts = d['1On Mcroscope'].value_counts()


# Calculate the frequency distribution with custom bins
frequency_distribution = pd.cut(d['1On Mcroscope'], bins=bins).value_counts()


# Normalize the frequency distribution by dividing by the total counts
normalized_distribution = frequency_distribution / group_counts

# Print the normalized distribution

print(frequency_distribution)
print(normalized_distribution)
# Out:
# (-1, 0]     12
# (0, 1]      11
# (5, 10]      4
# (1, 5]       3
# (10, 15]     0
# (15, 20]     0
# (20, 25]     0
# (25, 30]     0
# (30, 35]     0
# (35, 40]     0
# (40, 45]     0
# (45, 50]     0
# Name: 1On Mcroscope, dtype: int64
# (-1, 0]    NaN
# (0, 1]     NaN
# (5, 10]    NaN
# (1, 5]     NaN
# (10, 15]   NaN
# (15, 20]   NaN
# (20, 25]   NaN
# (25, 30]   NaN
# (30, 35]   NaN
# (35, 40]   NaN
# (40, 45]   NaN
# (45, 50]   NaN
# 0.0        NaN
# 1.0        NaN
# 5.0        NaN
# 10.0       NaN
# 6.0        NaN
# 8.0        NaN
# 4.0        NaN
# Name: 1On Mcroscope, dtype: float64
# /var/folders/k3/54x11nt55_17p1yfsph643kc0000gn/T/ipykernel_18457/1979219057.py:15: RuntimeWarning: '<' not supported between instances of 'float' and 'pandas._libs.interval.Interval', sort order is undefined for incomparable objects.
#   normalized_distribution = frequency_distribution / group_counts

# %%
bins = [-1, 0, 1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]


# Calculate the total number of samples in each group
group_counts = d['1On Laser'].value_counts()


# Calculate the frequency distribution with custom bins
frequency_distribution = pd.cut(d['1On Laser'], bins=bins).value_counts()


# Normalize the frequency distribution by dividing by the total counts
normalized_distribution = frequency_distribution / group_counts

# Print the normalized distribution

print(frequency_distribution)
print(normalized_distribution)
# Out:
# (-1, 0]     8
# (0, 1]      4
# (1, 5]      2
# (5, 10]     1
# (10, 15]    0
# (15, 20]    0
# (20, 25]    0
# (25, 30]    0
# (30, 35]    0
# (35, 40]    0
# (40, 45]    0
# (45, 50]    0
# Name: 1On Laser, dtype: int64
# (-1, 0]    NaN
# (0, 1]     NaN
# (1, 5]     NaN
# (5, 10]    NaN
# (10, 15]   NaN
# (15, 20]   NaN
# (20, 25]   NaN
# (25, 30]   NaN
# (30, 35]   NaN
# (35, 40]   NaN
# (40, 45]   NaN
# (45, 50]   NaN
# 0.0        NaN
# 1.0        NaN
# 6.0        NaN
# 3.0        NaN
# 2.0        NaN
# Name: 1On Laser, dtype: float64
# /var/folders/k3/54x11nt55_17p1yfsph643kc0000gn/T/ipykernel_18457/1507086197.py:15: RuntimeWarning: '<' not supported between instances of 'float' and 'pandas._libs.interval.Interval', sort order is undefined for incomparable objects.
#   normalized_distribution = frequency_distribution / group_counts

# %%
### All both live and death at the end of imaging

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
d=pd.read_csv('/Users/shruthibalachandra/Documents/Shruthi_for_mac/Amodeo_Lab/Python/BM_status_fecundity_v3.csv')


plt.figure(figsize = (4,3))
plt.style.use('seaborn')
sns.set_style("whitegrid")
sns.set_palette


sns.barplot(x='1FAll_Bins', y='1FAll_NFrequency', data=d, palette='viridis', hue='1FAll_Status', ci=None)

kwargs = {'edgecolor':'0.2', 'linewidth':1.5, 'fc': 'none'}


# Additional plot customizations
plt.xlabel('Number of eggs/female', fontsize=10)
plt.ylabel('Percent of females', fontsize=10)
plt.legend([])
plt.xticks(size=10)
plt.yticks(size=10)

# Save the plot as a PNG file
plt.savefig('/Users/shruthibalachandra/Documents/Shruthi_for_mac/Amodeo_Lab/Python/BM_Figure_Plots/Allimaged_BM_egg_1h.pdf', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
#Libraries
import numpy as np
import pandas as pd
from scipy import stats

# Assuming d is your DataFrame containing the data

# Drop rows with NaN values
d_clean = d.dropna(subset=['1InVial'])

# Sample data
InVial = d_clean['1InVial']
OnBench = d_clean['1On Bench']
OnMcroscope = d_clean['1On Mcroscope']
OnLaser = d_clean['1On Laser']

# Mean
mean = np.mean(InVial)

# Median
median = np.median(InVial)

# Standard Deviation
std_dev = np.std(InVial)

# Standard Error of the Mean (SEM)
sem = stats.sem(InVial)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
print("Standard Error of the Mean:", sem)
# Out:
# Mean: 15.075
# Median: 11.5
# Standard Deviation: 12.935199070752642
# Standard Error of the Mean: 2.071289546300899

# %%
#Libraries
import numpy as np
import pandas as pd
from scipy import stats

# Assuming d is your DataFrame containing the data

# Drop rows with NaN values
d_clean = d.dropna(subset=['1On Bench'])

# Sample data

OnBench = d_clean['1On Bench']

# Mean
mean = np.mean(OnBench)

# Median
median = np.median(OnBench)

# Standard Deviation
std_dev = np.std(OnBench)

# Standard Error of the Mean (SEM)
sem = stats.sem(OnBench)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
print("Standard Error of the Mean:", sem)
# Out:
# Mean: 4.659090909090909
# Median: 1.0
# Standard Deviation: 8.431389354446928
# Standard Error of the Mean: 1.2857748224706993

# %%
#Libraries
import numpy as np
import pandas as pd
from scipy import stats

# Assuming d is your DataFrame containing the data

# Drop rows with NaN values
d_clean = d.dropna(subset=['1On Mcroscope'])

# Sample data

OnMcroscope = d_clean['1On Mcroscope']

# Mean
mean = np.mean(OnMcroscope)

# Median
median = np.median(OnMcroscope)

# Standard Deviation
std_dev = np.std(OnMcroscope)

# Standard Error of the Mean (SEM)
sem = stats.sem(OnMcroscope)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
print("Standard Error of the Mean:", sem)
# Out:
# Mean: 1.9666666666666666
# Median: 1.0
# Standard Deviation: 2.9493878837631526
# Standard Error of the Mean: 0.547687580490698

# %%
#Libraries
import numpy as np
import pandas as pd
from scipy import stats

# Assuming d is your DataFrame containing the data

# Drop rows with NaN values
d_clean = d.dropna(subset=['1On Laser'])

# Sample data

OnLaser = d_clean['1On Laser']

# Mean
mean = np.mean(OnLaser)

# Median
median = np.median(OnLaser)

# Standard Deviation
std_dev = np.std(OnLaser)

# Standard Error of the Mean (SEM)
sem = stats.sem(OnLaser)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
print("Standard Error of the Mean:", sem)
# Out:
# Mean: 1.0
# Median: 0.0
# Standard Deviation: 1.591644851508443
# Standard Error of the Mean: 0.42538497969766276

# %%
#Libraries
import numpy as np
import pandas as pd
from scipy import stats

# Assuming d is your DataFrame containing the data

# Drop rows with NaN values
d_clean = d.dropna(subset=['1InVial', '1On Bench', '1On Mcroscope', '1On Laser'])

# Sample data
InVial = d_clean['1InVial']
OnBench = d_clean['1On Bench']
OnMcroscope = d_clean['1On Mcroscope']
OnLaser = d_clean['1On Laser']

# Perform t-test between InVial and OnBench
t_statistic, p_value = stats.ttest_ind(InVial, OnBench, equal_var=False)  # Assuming unequal variances

print("T-Statistic:", t_statistic)
print("P-value:", p_value)

# Perform t-test between InVial and OnMcroscope
t_statistic, p_value = stats.ttest_ind(InVial, OnMcroscope, equal_var=False)  # Assuming unequal variances

print("T-Statistic:", t_statistic)
print("P-value:", p_value)

# Perform t-test between InVial and OnLaser
t_statistic, p_value = stats.ttest_ind(InVial, OnLaser, equal_var=False)  # Assuming unequal variances

print("T-Statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-Statistic: 3.144497877423784
# P-value: 0.005043306297784411
# T-Statistic: 3.578435837860626
# P-value: 0.002618437328903358
# T-Statistic: 3.939553986278159
# P-value: 0.0014014425487257611
